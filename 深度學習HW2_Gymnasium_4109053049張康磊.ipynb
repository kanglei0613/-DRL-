# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)

# %%
import gymnasium as gym

# %%
env=gym.make('MountainCarContinuous-v0',render_mode='rgb_array')

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (1,), float32)

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
env.reward_range
# Out:
# (-inf, inf)

# %%
env.reset()
# Out:
# (array([-0.47892275,  0.        ], dtype=float32), {})

# %%
img=env.render()
img.shape
# Out:
# (400, 600, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
env=gym.make('MountainCarContinuous-v0',render_mode='rgb_array')

# %%
env.reset()
# Out:
# (array([-0.52028096,  0.        ], dtype=float32), {})

# %%
env.step((0.75,))
# Out:
# (array([-0.39745298, -0.00736034], dtype=float32), -0.05625, False, False, {})

# %%
img=env.render()

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
len(img),img[0].shape,img[1].shape
# Out:
# (400, (600, 3), (600, 3))

# %%
plt.imshow(img)
plt.show()

# %%
env=gym.make('MountainCarContinuous-v0',render_mode='human')

# %%
env.reset()
# Out:
# (array([-0.54910624,  0.        ], dtype=float32), {})

# %%
a=env.action_space.sample()
a
# Out:
# array([0.69437194], dtype=float32)

# %%
env.step(a)
# Out:
# (array([-0.54787356,  0.00123268], dtype=float32),
#  -0.048215238926155736,
#  False,
#  False,
#  {})

# %%
n_t=20

# %%
s=env.reset()
for t in range(n_t):
  a=env.action_space.sample()
  s1,r,done,_,_=env.step(a)
  print('t=',t,'s=',s,'a=',a,'r=',r,'s\'=',s1,'done=',done)
  s=s1
  if done:
    break
# Out:
# t= 0 s= (array([-0.54102015,  0.        ], dtype=float32), {}) a= [0.5854735] r= -0.0342779193254561 s'= [-0.54001135  0.00100881] done= False
# t= 1 s= [-0.54001135  0.00100881] a= [-0.82405406] r= -0.06790650977027078 s'= [-5.4011559e-01 -1.0422549e-04] done= False
# t= 2 s= [-5.4011559e-01 -1.0422549e-04] a= [0.23141825] r= -0.005355440735469586 s'= [-5.3974885e-01  3.6672736e-04] done= False
# t= 3 s= [-5.3974885e-01  3.6672736e-04] a= [-0.8952602] r= -0.08014908522137745 s'= [-0.54060394 -0.00085508] done= False
# t= 4 s= [-0.54060394 -0.00085508] a= [-0.654275] r= -0.04280757757497931 s'= [-0.5423129  -0.00170901] done= False
# t= 5 s= [-0.5423129  -0.00170901] a= [0.10078704] r= -0.0010158026650033904 s'= [-0.5437305  -0.00141755] done= False
# t= 6 s= [-0.5437305  -0.00141755] a= [-0.2604875] r= -0.006785373601667644 s'= [-0.54538786 -0.00165739] done= False
# t= 7 s= [-0.54538786 -0.00165739] a= [-0.7015176] r= -0.04921269177705199 s'= [-0.54793423 -0.00254636] done= False
# t= 8 s= [-0.54793423 -0.00254636] a= [0.8093764] r= -0.06550901869704583 s'= [-0.5490842  -0.00114994] done= False
# t= 9 s= [-0.5490842  -0.00114994] a= [0.25491866] r= -0.006498352560928656 s'= [-0.5496608  -0.00057661] done= False
# t= 10 s= [-0.5496608  -0.00057661] a= [-0.14969409] r= -0.0022408319120259534 s'= [-0.5502667  -0.00060588] done= False
# t= 11 s= [-0.5502667  -0.00060588] a= [0.927385] r= -0.08600428873529752 s'= [-0.5492817   0.00098499] done= False
# t= 12 s= [-0.5492817   0.00098499] a= [0.16905122] r= -0.0028578313310761994 s'= [-0.5478507  0.001431 ] done= False
# t= 13 s= [-0.5478507  0.001431 ] a= [0.7121273] r= -0.050712533116906405 s'= [-0.54516983  0.00268092] done= False
# t= 14 s= [-0.54516983  0.00268092] a= [-0.92769593] r= -0.08606197385462089 s'= [-0.5437188   0.00145104] done= False
# t= 15 s= [-0.5437188   0.00145104] a= [-0.8724412] r= -0.0761153599647301 s'= [-5.4342562e-01  2.9319033e-04] done= False
# t= 16 s= [-5.4342562e-01  2.9319033e-04] a= [0.17654428] r= -0.003116788239822999 s'= [-0.542719    0.00070662] done= False
# t= 17 s= [-0.542719    0.00070662] a= [-0.6843226] r= -0.04682974148436756 s'= [-5.4289556e-01 -1.7654039e-04] done= False
# t= 18 s= [-5.4289556e-01 -1.7654039e-04] a= [0.27679998] r= -0.007661822717071587 s'= [-5.4251224e-01  3.8330461e-04] done= False
# t= 19 s= [-5.4251224e-01  3.8330461e-04] a= [0.41492173] r= -0.017216004265418496 s'= [-0.5413648   0.00114746] done= False

# %%
import time
from IPython.display import clear_output
def game_display(img):
  plt.imshow(img)
  plt.show()
  time.sleep(0.5)
  clear_output(wait=True)

env=gym.make('MountainCarContinuous-v0',render_mode='rgb_array')

# %%
n_t=100

# %%
s=env.reset()
game_display(env.render())
for t in range(n_t):
  a=env.action_space.sample()
  s1,r,done,_,_=env.step(a)
  print('t=',t,'s=',s,'a=',a,'r=',r,'s\'=',s1,'done=',done)
  game_display(env.render())
  s=s1
  if done:
    break
# Out:
# t= 99 s= [-0.4885949  -0.00334503] a= [0.05895678] r= -0.0003475901853679242 s'= [-0.49211353 -0.00351865] done= False
